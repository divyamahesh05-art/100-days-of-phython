# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamahesh05-art/100-days-of-phython/blob/main/Uday_2_phyrho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# integer,float,basic mahth operator,f string,

# %%
num1=10
num2=3
sum=num1+num2
div=num1/num2
sub=num1-num2
mul=num1*num2
power=num1**num2
mod=num1%num2
print(sum)
print(div)
print(sub)
print(mul)
print(power)
print(mod)
# Out:
# 13
# 3.3333333333333335
# 7
# 30
# 1000
# 1

# %%
hours_studied=int(input("how many hours studied"))
weekly_projection=hours_studied*7
print("in 7 days,you  will study:",weekly_projection)
# Out:
# how many hours studied10
# in 7 days,you  will study: 70

# %%
name="DIVYA"
DAY=2
GOAL=1.5
print(f"hello{name}!welcometo day{DAY}ofphython.today target is {GOAL}hours ")
# Out:
# helloDIVYA!welcometo day2ofphython.today target is 1.5hours

# %%
year_birth =int(input("what is year of birth"))
age=2026-year_birth
print(f"dearu u r age is {age} in this year 2026 ")
# Out:
# what is year of birth1988
# dearu u r age is 38 in this year 2026

# %%
producut_name=input("name of product")
pric_product=float(input("price of product"))
quantity=int(input("quantity"))
total_cost=pric_product*quantity
print(f"""---bill summarry---
product name:{producut_name}
price peritem:{pric_product}
      quantity{quantity}
      total cost:{total_cost}
      thankyou for shopping!""")
# Out:
# name of productpol
# price of product6.3
# quantity25
# ---bill summarry---
# product name:pol
# price peritem:6.3
#       quantity25
#       total cost:157.5
#       thankyou for shopping!
