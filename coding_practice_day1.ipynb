# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamahesh05-art/100-days-of-phython/blob/main/coding_practice_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("helloe divya")
print('welcometo day 1 of pythoncoding')
# Out:
# helloe divya
# welcometo day 1 of pythoncoding

# %%
course_name="phythondata analydsis"
total_days=100
daily_hours=1.0
print(course_name)
print(total_days)
print(daily_hours)
# Out:
# phythondata analydsis
# 100
# 1.0

# %%
from pathlib import PureWindowsPath
user_name= input("what is urname?")
target_goal= input("what is u r main goal for coding?")
print('yur summary')
print("name:",user_name)
print("goal:",target_goal)
# Out:
# what is urname?divya
# what is u r main goal for coding?career updte
# yur summary
# name: divya
# goal: career updte

# %%
my_name="divya mahesh"
topic="phython fundamaentals"
print("my name is",my_name)
print(' i would like to study',topic )
# Out:
# my name is divya mahesh
#  i would like to study phython fundamaentals

# %%
steps=input("how many steps did wlak today?")
# Out:
# how many steps did wlak today?5000

# %%
print("hello",my_name,"iam studying",topic)
print("great job walking",steps,"steps today!")
# Out:
# hello divya mahesh iam studying phython fundamaentals
# great job walking 5000 steps today!
