# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamahesh05-art/100-days-of-phython/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("what is ur age?"))
if age>=18:
  print("you are eligible for drivinf license")
else:
    print("you are nor eligible")
# Out:
# what is ur age?2
# you are nor eligible

# %%
sugar_level=float(input("enter u r fasting blood glucose value"))
if sugar_level<100:
  print("normal")
elif sugar_level>=100 and sugar_level<=125:
  print("pre-diabetic")
else:
  print("diabetic")
# Out:
# enter u r fasting blood glucose value560
# diabetic

# %%
daily_steps=int(input("total steps wlked"))
if daily_steps>10000:
  print("awsome!you are a healthy person")
elif daily_steps >=5000 and daily_steps <=9999:
  print("good effort!almost tere")
else:
  print("you are not healthy")
# Out:
# total steps wlked96325
# awsome!you are a healthy person

# %%
bmi=float(input("enter ur bmi"))
if bmi<18.5:
  print("underweight")
elif bmi>=18.5 and bmi<=24.9:
  print("normal")
elif bmi>=25 and bmi<=29.9:
  print("overweight")
else:
  print("obese")
# Out:
# enter ur bmi30
# obese

# %%
test_name=input("what test u want to do")
price_test=float(input("what is the price"))
discount=price_test*0.15
urgency_fee=price_test+50
age=int(input("what is u r age"))
urgent_stsus=input("yes or no")
if age >=60  and discount:
  print("you are senour citizen")
else:
  print("you are not eligible")
if urgent_stsus=="yes" and price_test+50:
  print("emergency")
else:
  print("not uregent")
print(f""" ------lab bill recepit-----
test name:{test_name}
      orginal price:{price_test}
      dicount:{discount:.2f}
      urgrncy fee{urgency_fee}""")
# Out:
# what test u want to dodfff
# what is the price23
# what is u r age23
# yes or noyes
# you are not eligible
# emergency
#  ------lab bill recepit-----
# test name:dfff
#       orginal price:23.0
#       dicount:3.45
#       urgrncy fee73.0

# %% [markdown]
# .2f help to remove decimels
